# %%
# %load_ext autoreload
# %autoreload 2

import sys

import matplotlib.pyplot as plt

sys.path.append("../../src")
from ct_plots import (
    compare_sweeps,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### All Force Sweeps

# %%
fig, ax = compare_sweeps(
    ["006", "007", "008", "009", "010"],
)
fig.suptitle("CT Power Harvesting with Clamping Force")
fig.savefig("../../figures/compare_003_008_full.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
fig, ax = compare_sweeps(
    ["012"],
    x="line_current_A",
    xlabel="Line Current (A)",
)
fig.suptitle("POC 2.0 CT's Power Harvesting")

fig.savefig("../../figures/sample_output.png", dpi=100, bbox_inches="tight")  # README
